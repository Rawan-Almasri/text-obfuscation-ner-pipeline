# %% [markdown]
# <a href="https://colab.research.google.com/github/Rawan-Almasri/text-obfuscation-ner-pipeline/blob/main/text_obfuscation_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
# !pip install python-docx
from docx import Document
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (5.4.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def get_file_path():
  # file_name = input ()
  file_name = "text_example.docx"
  file_path  = f"/content/drive/MyDrive/{file_name}"
  return file_path

# %%
def read_file(file_path):

    # Check if file exists
    if not os.path.exists(file_path):
        return "File not found!"

    # Read text file
    if file_path.endswith(".txt"):
        with open(file_path, "r", encoding="utf-8") as f:
            content = f.read()
        return content

    # Read word file
    elif file_path.endswith(".docx"):
        doc = Document(file_path)
        content = "\n".join([para.text for para in doc.paragraphs])
        return content

    else:
        return "Unsupported file type. Please provide a .txt or .docx file."

# %%
def get_enities():
  arr = input("Enter categories of entities to anonymize: ").split()
  # print("The entities are:", arr)
  return arr

# %%
# !pip install gliner==0.1.12
# Out:
# Requirement already satisfied: gliner==0.1.12 in /usr/local/lib/python3.12/dist-packages (0.1.12)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (2.8.0+cu126)
# Requirement already satisfied: transformers>=4.38.2 in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (4.56.1)
# Requirement already satisfied: huggingface-hub>=0.21.4 in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (0.35.0)
# Requirement already satisfied: flair==0.13.1 in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (0.13.1)
# Requirement already satisfied: scipy<=1.12 in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (1.12.0)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (1.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gliner==0.1.12) (4.67.1)
# Requirement already satisfied: boto3>=1.20.27 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (1.40.36)
# Requirement already satisfied: bpemb>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.3.6)
# Requirement already satisfied: conllu>=4.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (6.0.0)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (1.2.18)
# Requirement already satisfied: ftfy>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (6.3.1)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (5.2.0)
# Requirement already satisfied: gensim>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (4.3.3)
# Requirement already satisfied: janome>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.5.0)
# Requirement already satisfied: langdetect>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (1.0.9)
# Requirement already satisfied: lxml>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (5.4.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (3.10.0)
# Requirement already satisfied: more-itertools>=8.13.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (10.8.0)
# Requirement already satisfied: mpld3>=0.3 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.5.11)
# Requirement already satisfied: pptree>=3.1 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (2.9.0.post0)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.2.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (2024.11.6)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (1.6.1)
# Requirement already satisfied: segtok>=1.5.11 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (1.5.11)
# Requirement already satisfied: sqlitedict>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (2.1.0)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.9.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.4.2)
# Requirement already satisfied: urllib3<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (1.26.20)
# Requirement already satisfied: wikipedia-api>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (0.8.1)
# Requirement already satisfied: semver<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from flair==0.13.1->gliner==0.1.12) (3.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.21.4->gliner==0.1.12) (1.1.10)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in /usr/local/lib/python3.12/dist-packages (from scipy<=1.12->gliner==0.1.12) (1.26.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->gliner==0.1.12) (3.4.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.38.2->gliner==0.1.12) (0.22.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.38.2->gliner==0.1.12) (0.6.2)
# Requirement already satisfied: botocore<1.41.0,>=1.40.36 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.20.27->flair==0.13.1->gliner==0.1.12) (1.40.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.20.27->flair==0.13.1->gliner==0.1.12) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.20.27->flair==0.13.1->gliner==0.1.12) (0.14.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from bpemb>=0.3.2->flair==0.13.1->gliner==0.1.12) (0.2.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated>=1.2.13->flair==0.13.1->gliner==0.1.12) (1.17.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy>=6.1.0->flair==0.13.1->gliner==0.1.12) (0.2.13)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.4.0->flair==0.13.1->gliner==0.1.12) (4.13.5)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim>=4.2.0->flair==0.13.1->gliner==0.1.12) (7.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from langdetect>=1.0.9->flair==0.13.1->gliner==0.1.12) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->flair==0.13.1->gliner==0.1.12) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->flair==0.13.1->gliner==0.1.12) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->flair==0.13.1->gliner==0.1.12) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->flair==0.13.1->gliner==0.1.12) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->flair==0.13.1->gliner==0.1.12) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2.3->flair==0.13.1->gliner==0.1.12) (3.2.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->flair==0.13.1->gliner==0.1.12) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.2->flair==0.13.1->gliner==0.1.12) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->gliner==0.1.12) (1.3.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece]<5.0.0,>=4.18.0->flair==0.13.1->gliner==0.1.12) (5.29.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->gliner==0.1.12) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21.4->gliner==0.1.12) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21.4->gliner==0.1.12) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.21.4->gliner==0.1.12) (2025.8.3)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece,torch]<5.0,>=4.1->transformer-smaller-training-vocab>=0.2.3->flair==0.13.1->gliner==0.1.12) (1.10.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.4.0->flair==0.13.1->gliner==0.1.12) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.4.0->flair==0.13.1->gliner==0.1.12) (1.7.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.0->transformers[sentencepiece,torch]<5.0,>=4.1->transformer-smaller-training-vocab>=0.2.3->flair==0.13.1->gliner==0.1.12) (5.9.5)

# %%
from gliner import GLiNER
model = GLiNER.from_pretrained("numind/NuNerZero")

def merge_entities(entities, text):
    if not entities:
        return []
    merged = []
    current = entities[0].copy()   # copy to avoid mutating original dicts
    for next_entity in entities[1:]:
        if next_entity['label'] == current['label'] and (next_entity['start'] == current['end'] or next_entity['start'] == current['end'] + 1):
            current['text'] = text[current['start']: next_entity['end']].strip()
            current['end'] = next_entity['end']
        else:
            merged.append(current)
            current = next_entity.copy()
    merged.append(current)
    return merged
# Out:
# Fetching 0 files: 0it [00:00, ?it/s]

# %%
def use_model(labels,text):
# NuZero requires labels to be lower-cased!
  labels = [l.lower() for l in labels]
  entities = model.predict_entities(text, labels)
  entities = merge_entities(entities, text)   # <-- pass text here
  # entities = merge_entities(entities)
  for entity in entities:
    print(entity["text"], "=>", entity["label"], "-" ,entity ['score'])
  return entities

# %%
def anonymize_text(text, entities):
    if not entities:
        return text

    entities = sorted(entities, key=lambda e: e['start'])

    anonymized = []
    last_idx = 0

    for ent in entities:
        anonymized.append(text[last_idx:ent['start']])
        anonymized.append("****")
        last_idx = ent['end']

    anonymized.append(text[last_idx:])

    return "".join(anonymized)

# %%
def crete_file_to_save(anonymized_text, origin_file_path):
  if origin_file_path.endswith(".txt"):
    file_path = "/content/drive/MyDrive/anonymized_text_file.txt"
    with open(file_path, "w", encoding="utf-8") as f:
       f.write(anonymized_text)
    print(f"TXT file saved at: {file_path}")
  else :
    doc = Document()
    doc.add_heading("Anonymized_text_file", 0)
    doc.add_paragraph(anonymized_text)
    file_path = "/content/drive/MyDrive/anonymized_text_file.docx"
    doc.save(file_path)
    print(f"Word file saved at: {file_path}")

# %%
#pipeline
file = get_file_path()
file_content = read_file (file)
print (f"The content is {file_content}")
enities = get_enities()
# the input is:
#person organization location country
result_entities  = use_model(enities,file_content)
anonymized_text  = anonymize_text(file_content, result_entities)
print(anonymized_text)
crete_file_to_save (anonymized_text , file)
# Out:
# The content is In 2022, Elon Musk visited Berlin, Germany, to meet with executives from Tesla and discuss the expansion of the Gigafactory in Europe.
# During the same trip, he also gave a talk at the Technical University of Berlin about the future of electric vehicles and sustainable energy.
# Later that year, Musk attended a conference in San Francisco, where he met with representatives from Google and Microsoft to explore opportunities in artificial intelligence.
# Meanwhile, Angela Merkel, the former Chancellor of Germany, praised the collaboration between European countries and the United States in advancing green technologies.
# At the same time, the United Nations organized a summit in New York City, gathering leaders from organizations like the World Health Organization and UNICEF to address global health challenges.
# Enter categories of entities to anonymize: person organization location country
# Elon Musk => person - 0.999902606010437
# Berlin => location - 0.9833258390426636
# Germany => country - 0.9785116314888
# Tesla => organization - 0.9970327615737915
# Gigafactory => organization - 0.8980690836906433
# Europe => location - 0.9092884659767151
# Technical University of Berlin => organization - 0.9920591115951538
# San Francisco => location - 0.9930375218391418
# Google => organization - 0.9966384172439575
# Microsoft => organization - 0.9960700273513794
# Angela Merkel => person - 0.9998610019683838
# Germany => country - 0.9541242718696594
# United States => country - 0.9067288041114807
# United Nations => organization - 0.9290083050727844
# New York City => location - 0.9906030893325806
# World Health Organization => organization - 0.9976849555969238
# UNICEF => organization - 0.9963605999946594
# In 2022, **** visited ****, ****, to meet with executives from **** and discuss the expansion of the **** in ****.
# During the same trip, he also gave a talk at the **** about the future of electric vehicles and sustainable energy.
# Later that year, Musk attended a conference in ****, where he met with representatives from **** and **** to explore opportunities in artificial intelligence.
# Meanwhile, ****, the former Chancellor of ****, praised the collaboration between European countries and the **** in advancing green technologies.
# At the same time, the **** organized a summit in ****, gathering leaders from organizations like the **** and **** to address global health challenges.
# Word file saved at: /content/drive/MyDrive/anonymized_text_file.docx
